# %%
#Connecting to the database

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:7558@localhost:5434/cancer_metrics')

# %%
from sqlalchemy import inspect

# %%
insp = inspect(engine)
insp.get_table_names()
# Out:
# ['data_diagnosis',
#  'data_mean',
#  'data_se',
#  'data_worst',
#  'breast_cancer_metrics',
#  'cancer_metrics',
#  'final_metrics']

# %%
import pandas as pd

# %%
df = pd.read_sql('SELECT * from final_metrics LIMIT 10', engine)

# %%
df
# Out:
#   diagnosis       id_no  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M    842302.0        17.99         10.38          122.80     1001.0
# 1         M    842517.0        20.57         17.77          132.90     1326.0
# 2         M  84300903.0        19.69         21.25          130.00     1203.0
# 3         M  84348301.0        11.42         20.38           77.58      386.1
# 4         M  84358402.0        20.29         14.34          135.10     1297.0
# 5         M    843786.0        12.45         15.70           82.57      477.1
# 6         M    844359.0        18.25         19.98          119.60     1040.0
# 7         M  84458202.0        13.71         20.83           90.20      577.9
# 8         M    844981.0        13.00         21.82           87.50      519.8
# 9         M  84501001.0        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...
